# %%
from iapt_classes_global import g
from iapt_classes_trial import Trial

g.sim_duration = 3
g.mean_referrals_pw = 20
g.debug_level = 2

# %%
my_trial = Trial()
#pd.set_option('display.max_rows', 1000)
# Call the run_trial method of our Trial class object

step2_results_df, step2_sessions_df, step3_results_df, step3_sessions_df, asst_weekly_dfs, step2_waiting_dfs, step3_waiting_dfs, staff_weekly_dfs, caseload_weekly_dfs  = my_trial.run_trial()
# Out:
# {'PwP_0': {}, 'PwP_1': {}, 'PwP_2': {}, 'PwP_3': {}, 'PwP_4': {}, 'PwP_5': {}, 'PwP_6': {}, 'PwP_7': {}, 'PwP_8': {}, 'PwP_9': {}, 'PwP_10': {}, 'PwP_11': {}}
# {'CBT_0': {}, 'CBT_1': {}, 'CBT_2': {}, 'CBT_3': {}, 'CBT_4': {}, 'CBT_5': {}, 'CBT_6': {}, 'CBT_7': {}, 'CBT_8': {}, 'CBT_9': {}, 'CBT_10': {}, 'CBT_11': {}, 'CBT_12': {}, 'CBT_13': {}}
# {'Couns_0': {}, 'Couns_1': {}, 'Couns_2': {}, 'Couns_3': {}}
# Building Sim Resources
# Sim Resources Ready
# Caseload Resources Ready
#
#                 #################################
#                         Week Number 0
#                 #################################
#
# Topping Up Resources
# Topping Up Caseloads
# PwP Resource PwP_0 now at: 30
# PwP Resource PwP_1 now at: 30
# PwP Resource PwP_2 now at: 30
# PwP Resource PwP_3 now at: 30
# PwP Resource PwP_4 now at: 30
# PwP Resource PwP_5 now at: 30
# PwP Resource PwP_6 now at: 30
# PwP Resource PwP_7 now at: 30
# PwP Resource PwP_8 now at: 30
# PwP Resource PwP_9 now at: 30
# PwP Resource PwP_10 now at: 30
# PwP Resource PwP_11 now at: 30
# Couns Resource CBT_0 now at: 25
# Couns Resource CBT_1 now at: 25
# Couns Resource CBT_2 now at: 25
# Couns Resource CBT_3 now at: 25
# Couns Resource CBT_4 now at: 25
# Couns Resource CBT_5 now at: 25
# Couns Resource CBT_6 now at: 25
# Couns Resource CBT_7 now at: 25
# Couns Resource CBT_8 now at: 25
# Couns Resource CBT_9 now at: 25
# Couns Resource CBT_10 now at: 25
# Couns Resource CBT_11 now at: 25
# Couns Resource CBT_12 now at: 25
# Couns Resource CBT_13 now at: 25
# PwP Resource Couns_0 now at: 25
# PwP Resource Couns_1 now at: 25
# PwP Resource Couns_2 now at: 25
# PwP Resource Couns_3 now at: 25
# Firing up the staff entity generator
#
# ==== PwP Staff 101.0 Generated ====
#
# ==== PwP Staff 102.0 Generated ====
#
# ==== PwP Staff 103.0 Generated ====
#
# ==== PwP Staff 104.0 Generated ====
#
# ==== PwP Staff 105.0 Generated ====
#
# ==== PwP Staff 106.0 Generated ====
#
# ==== PwP Staff 107.0 Generated ====
#
# ==== PwP Staff 108.0 Generated ====
#
# ==== PwP Staff 109.0 Generated ====
#
# ==== PwP Staff 110.0 Generated ====
#
# ==== PwP Staff 111.0 Generated ====
#
# ==== PwP Staff 112.0 Generated ====
#
# ==== PwP Staff 113.0 Generated ====
#
# ==== PwP Staff 114.0 Generated ====
#
# ==== PwP Staff 115.0 Generated ====
#
# ==== PwP Staff 116.0 Generated ====
#
# ==== PwP Staff 117.0 Generated ====
#
# ==== PwP Staff 118.0 Generated ====
#
# ==== PwP Staff 119.0 Generated ====
#
# ==== PwP Staff 120.0 Generated ====
#
# ==== PwP Staff 121.0 Generated ====
#
# ==== PwP Staff 122.0 Generated ====
#
# ==== PwP Staff 123.0 Generated ====
#
# ==== PwP Staff 124.0 Generated ====
#
# ==== CBT Staff 201.0 Generated ====
#
# ==== CBT Staff 202.0 Generated ====
#
# ==== CBT Staff 203.0 Generated ====
#
# ==== CBT Staff 204.0 Generated ====
#
# ==== CBT Staff 205.0 Generated ====
#
# ==== CBT Staff 206.0 Generated ====
#
# ==== CBT Staff 207.0 Generated ====
#
# ==== CBT Staff 208.0 Generated ====
#
# ==== CBT Staff 209.0 Generated ====
#
# ==== CBT Staff 210.0 Generated ====
#
# ==== CBT Staff 211.0 Generated ====
#
# ==== CBT Staff 212.0 Generated ====
#
# ==== CBT Staff 213.0 Generated ====
#
# ==== CBT Staff 214.0 Generated ====
#
# ==== CBT Staff 215.0 Generated ====
#
# ==== CBT Staff 216.0 Generated ====
#
# ==== CBT Staff 217.0 Generated ====
#
# ==== CBT Staff 218.0 Generated ====
#
# ==== CBT Staff 219.0 Generated ====
#
# ==== CBT Staff 220.0 Generated ====
#
# ==== CBT Staff 221.0 Generated ====
#
# ==== CBT Staff 222.0 Generated ====
#
# ==== CBT Staff 223.0 Generated ====
#
# ==== CBT Staff 224.0 Generated ====
#
# ==== CBT Staff 225.0 Generated ====
#
# ==== CBT Staff 226.0 Generated ====
#
# ==== CBT Staff 227.0 Generated ====
#
# ==== CBT Staff 228.0 Generated ====
#
# ==== Couns Staff 301.0 Generated ====
#
# ==== Couns Staff 302.0 Generated ====
#
# ==== Couns Staff 303.0 Generated ====
#
# ==== Couns Staff 304.0 Generated ====
#
# ==== Couns Staff 305.0 Generated ====
#
# ==== Couns Staff 306.0 Generated ====
#
# ==== Couns Staff 307.0 Generated ====
#
# ==== Couns Staff 308.0 Generated ====
# Staff generator complete
# Firing up the referral generator
# Week 0: 17 referrals generated
# Referral generator has returned 17 referrals
# Passing 17 to the patient treatment generator
# Processing 17 referral through treatment
# Processing referral, 17 left out of 17
# Referral processed, proceeding to next referral, 16 left
# Processing referral, 16 left out of 17
#
# ==== Patient 1 Generated ====
# Referral Rejected for Patient 1
# Referral processed, proceeding to next referral, 15 left
# Processing referral, 15 left out of 17
#
# ==== Patient 2 Generated ====
# Referral Accepted flag set to 1.0 for Patient 2
# Patient 2 Sent For Review
# Patient 2 Reviewed and Rejection flag set to 1.0
# Patient 2 Rejected at Review
# Referral processed, proceeding to next referral, 14 left
# Processing referral, 14 left out of 17
#
# ==== Patient 3 Generated ====
# Referral Rejected for Patient 3
# Referral processed, proceeding to next referral, 13 left
# Processing referral, 13 left out of 17
#
# ==== Patient 4 Generated ====
# Referral Accepted flag set to 1.0 for Patient 4
# Patient 4 Sent For Review
# Patient 4 Reviewed and Rejection flag set to 0.0
# Patient 4 Accepted at Review - go to opt-in
# Patient 4 Opted In
# Patient 4 requesting TA resource, current res level 36
# Referral processed, proceeding to next referral, 12 left
# Processing referral, 12 left out of 17
#
# ==== Patient 5 Generated ====
# Referral Accepted flag set to 1.0 for Patient 5
# Patient 5 Didn't Need Review
# Patient 5 Did Not Require Review, Rejection flag set to 0.0
# Patient 5 did not require a Review - go to opt-in
# Patient 5 Failed to Opt In
# Patient 4 allocated TA resource, new res level 35
# Week 0: Patient number 4 (added week 0) put through TA
# Patient 4 waited 0 for assessment
# Patient 4 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 4 sent down **Step2** pathway
# PwP RUNNER: Patient 4 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_6 with a remaining caseload of 30 selected
# Referral processed, proceeding to next referral, 11 left
# Processing referral, 11 left out of 17
#
# ==== Patient 6 Generated ====
# Referral Rejected for Patient 6
# Referral processed, proceeding to next referral, 10 left
# Processing referral, 10 left out of 17
#
# ==== Patient 7 Generated ====
# Referral Accepted flag set to 1.0 for Patient 7
# Patient 7 Sent For Review
# Patient 7 Reviewed and Rejection flag set to 1.0
# Patient 7 Rejected at Review
# Resource PwP_6 with a caseload remaining of 29 allocated to patient 4
# Patient 4 added to caseload [] spaces left
# PwP RUNNER: Patient 4 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 0: Patient 4 (added week 0) put through PwP
# Patient 4 WEEK NUMBER 0 waited 0 weeks from 0 weeks to 0 to enter PwP treatment
# Random Session week 7 numbers are [0, 2, 4, 5, 9, 10, 12]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 0: Patient 4 (added week 0) on PwP Session 0 on Week 0
# FUNC PROCESS step2_pwp_process: Week 0: Patient 4 (added week 0) on PwP Session 1 on Week 2
# FUNC PROCESS step2_pwp_process: Week 0: Patient 4 (added week 0) on PwP Session 2 on Week 4
# FUNC PROCESS step2_pwp_process: Week 0: Patient 4 (added week 0) on PwP Session 3 on Week 5
# FUNC PROCESS step2_pwp_process: Week 0: Patient 4 (added week 0) on PwP Session 4 on Week 9
# FUNC PROCESS step2_pwp_process: Week 0: Patient 4 (added week 0) on PwP Session 5 on Week 10
# Resource PwP_6 usage recorded for week 12: {'week_number': 12, 'res_topup': 1}
# Referral processed, proceeding to next referral, 9 left
# Processing referral, 9 left out of 17
#
# ==== Patient 8 Generated ====
# Referral Rejected for Patient 8
# Referral processed, proceeding to next referral, 8 left
# Processing referral, 8 left out of 17
#
# ==== Patient 9 Generated ====
# Referral Rejected for Patient 9
# Referral processed, proceeding to next referral, 7 left
# Processing referral, 7 left out of 17
#
# ==== Patient 10 Generated ====
# Referral Accepted flag set to 1.0 for Patient 10
# Patient 10 Sent For Review
# Patient 10 Reviewed and Rejection flag set to 1.0
# Patient 10 Rejected at Review
# Referral processed, proceeding to next referral, 6 left
# Processing referral, 6 left out of 17
#
# ==== Patient 11 Generated ====
# Referral Accepted flag set to 1.0 for Patient 11
# Patient 11 Sent For Review
# Patient 11 Reviewed and Rejection flag set to 0.0
# Patient 11 Accepted at Review - go to opt-in
# Patient 11 Opted In
# Patient 11 requesting TA resource, current res level 35
# Referral processed, proceeding to next referral, 5 left
# Processing referral, 5 left out of 17
#
# ==== Patient 12 Generated ====
# Referral Accepted flag set to 1.0 for Patient 12
# Patient 12 Sent For Review
# Patient 12 Reviewed and Rejection flag set to 1.0
# Patient 12 Rejected at Review
# Patient 11 allocated TA resource, new res level 34
# Week 0: Patient number 11 (added week 0) put through TA
# Patient 11 waited 0 for assessment
# Patient 11 Rejected at TA Stage
# Referral processed, proceeding to next referral, 4 left
# Processing referral, 4 left out of 17
#
# ==== Patient 13 Generated ====
# Referral Accepted flag set to 1.0 for Patient 13
# Patient 13 Sent For Review
# Patient 13 Reviewed and Rejection flag set to 1.0
# Patient 13 Rejected at Review
# Referral processed, proceeding to next referral, 3 left
# Processing referral, 3 left out of 17
#
# ==== Patient 14 Generated ====
# Referral Accepted flag set to 1.0 for Patient 14
# Patient 14 Didn't Need Review
# Patient 14 Did Not Require Review, Rejection flag set to 0.0
# Patient 14 did not require a Review - go to opt-in
# Patient 14 Opted In
# Patient 14 requesting TA resource, current res level 34
# Referral processed, proceeding to next referral, 2 left
# Processing referral, 2 left out of 17
#
# ==== Patient 15 Generated ====
# Referral Accepted flag set to 1.0 for Patient 15
# Patient 15 Sent For Review
# Patient 15 Reviewed and Rejection flag set to 1.0
# Patient 15 Rejected at Review
# Patient 14 allocated TA resource, new res level 33
# Week 0: Patient number 14 (added week 0) put through TA
# Patient 14 waited 0 for assessment
# Patient 14 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 14 sent down **Step2** pathway
# PwP RUNNER: Patient 14 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_5 with a remaining caseload of 30 selected
# Referral processed, proceeding to next referral, 1 left
# Processing referral, 1 left out of 17
#
# ==== Patient 16 Generated ====
# Referral Accepted flag set to 1.0 for Patient 16
# Patient 16 Didn't Need Review
# Patient 16 Did Not Require Review, Rejection flag set to 0.0
# Patient 16 did not require a Review - go to opt-in
# Patient 16 Failed to Opt In
# Referral processed, proceeding to next referral, 0 left
#
# ==== Patient 17 Generated ====
# Referral Accepted flag set to 1.0 for Patient 17
# Patient 17 Sent For Review
# Patient 17 Reviewed and Rejection flag set to 1.0
# Patient 17 Rejected at Review
# Resource PwP_5 with a caseload remaining of 29 allocated to patient 14
# Patient 14 added to caseload [] spaces left
# PwP RUNNER: Patient 14 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 0: Patient 14 (added week 0) put through PwP
# Patient 14 WEEK NUMBER 0 waited 0 weeks from 0 weeks to 0 to enter PwP treatment
# Random Session week 7 numbers are [0, 2, 3, 9, 11, 12, 14]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 0: Patient 14 (added week 0) on PwP Session 0 on Week 0
# FUNC PROCESS step2_pwp_process: Week 0: Patient 14 (added week 0) on PwP Session 1 on Week 2
# Patient 14 dropped out of PwP treatment
# Resource PwP_5 usage recorded for week 2: {'week_number': 2, 'res_topup': 1}
# Collecting Weekly Stats
# Weekly Stats have been collected
# Week 0 complete, moving on to Week 1
#
#                 #################################
#                         Week Number 1
#                 #################################
#
# Topping Up Resources
# TA Level: 33
# Putting in 3
# New TA Level: 36
# Topping Up Caseloads
# PwP Resource PwP_0 now at: 30
# PwP Resource PwP_1 now at: 30
# PwP Resource PwP_2 now at: 30
# PwP Resource PwP_3 now at: 30
# PwP Resource PwP_4 now at: 30
# PwP Resource PwP_5 now at: 29
# PwP Resource PwP_6 now at: 29
# PwP Resource PwP_7 now at: 30
# PwP Resource PwP_8 now at: 30
# PwP Resource PwP_9 now at: 30
# PwP Resource PwP_10 now at: 30
# PwP Resource PwP_11 now at: 30
# Couns Resource CBT_0 now at: 25
# Couns Resource CBT_1 now at: 25
# Couns Resource CBT_2 now at: 25
# Couns Resource CBT_3 now at: 25
# Couns Resource CBT_4 now at: 25
# Couns Resource CBT_5 now at: 25
# Couns Resource CBT_6 now at: 25
# Couns Resource CBT_7 now at: 25
# Couns Resource CBT_8 now at: 25
# Couns Resource CBT_9 now at: 25
# Couns Resource CBT_10 now at: 25
# Couns Resource CBT_11 now at: 25
# Couns Resource CBT_12 now at: 25
# Couns Resource CBT_13 now at: 25
# PwP Resource Couns_0 now at: 25
# PwP Resource Couns_1 now at: 25
# PwP Resource Couns_2 now at: 25
# PwP Resource Couns_3 now at: 25
# Firing up the staff entity generator
#
# ==== PwP Staff 101.0 Generated ====
#
# ==== PwP Staff 102.0 Generated ====
#
# ==== PwP Staff 103.0 Generated ====
#
# ==== PwP Staff 104.0 Generated ====
#
# ==== PwP Staff 105.0 Generated ====
#
# ==== PwP Staff 106.0 Generated ====
#
# ==== PwP Staff 107.0 Generated ====
#
# ==== PwP Staff 108.0 Generated ====
#
# ==== PwP Staff 109.0 Generated ====
#
# ==== PwP Staff 110.0 Generated ====
#
# ==== PwP Staff 111.0 Generated ====
#
# ==== PwP Staff 112.0 Generated ====
#
# ==== PwP Staff 113.0 Generated ====
#
# ==== PwP Staff 114.0 Generated ====
#
# ==== PwP Staff 115.0 Generated ====
#
# ==== PwP Staff 116.0 Generated ====
#
# ==== PwP Staff 117.0 Generated ====
#
# ==== PwP Staff 118.0 Generated ====
#
# ==== PwP Staff 119.0 Generated ====
#
# ==== PwP Staff 120.0 Generated ====
#
# ==== PwP Staff 121.0 Generated ====
#
# ==== PwP Staff 122.0 Generated ====
#
# ==== PwP Staff 123.0 Generated ====
#
# ==== PwP Staff 124.0 Generated ====
#
# ==== CBT Staff 201.0 Generated ====
#
# ==== CBT Staff 202.0 Generated ====
#
# ==== CBT Staff 203.0 Generated ====
#
# ==== CBT Staff 204.0 Generated ====
#
# ==== CBT Staff 205.0 Generated ====
#
# ==== CBT Staff 206.0 Generated ====
#
# ==== CBT Staff 207.0 Generated ====
#
# ==== CBT Staff 208.0 Generated ====
#
# ==== CBT Staff 209.0 Generated ====
#
# ==== CBT Staff 210.0 Generated ====
#
# ==== CBT Staff 211.0 Generated ====
#
# ==== CBT Staff 212.0 Generated ====
#
# ==== CBT Staff 213.0 Generated ====
#
# ==== CBT Staff 214.0 Generated ====
#
# ==== CBT Staff 215.0 Generated ====
#
# ==== CBT Staff 216.0 Generated ====
#
# ==== CBT Staff 217.0 Generated ====
#
# ==== CBT Staff 218.0 Generated ====
#
# ==== CBT Staff 219.0 Generated ====
#
# ==== CBT Staff 220.0 Generated ====
#
# ==== CBT Staff 221.0 Generated ====
#
# ==== CBT Staff 222.0 Generated ====
#
# ==== CBT Staff 223.0 Generated ====
#
# ==== CBT Staff 224.0 Generated ====
#
# ==== CBT Staff 225.0 Generated ====
#
# ==== CBT Staff 226.0 Generated ====
#
# ==== CBT Staff 227.0 Generated ====
#
# ==== CBT Staff 228.0 Generated ====
#
# ==== Couns Staff 301.0 Generated ====
#
# ==== Couns Staff 302.0 Generated ====
#
# ==== Couns Staff 303.0 Generated ====
#
# ==== Couns Staff 304.0 Generated ====
#
# ==== Couns Staff 305.0 Generated ====
#
# ==== Couns Staff 306.0 Generated ====
#
# ==== Couns Staff 307.0 Generated ====
#
# ==== Couns Staff 308.0 Generated ====
# Staff generator complete
# Firing up the referral generator
# Week 1: 22 referrals generated
# Referral generator has returned 22 referrals
# Passing 22 to the patient treatment generator
# Processing 22 referral through treatment
# Processing referral, 22 left out of 22
# Referral processed, proceeding to next referral, 21 left
# Processing referral, 21 left out of 22
#
# ==== Patient 18 Generated ====
# Referral Rejected for Patient 18
# Referral processed, proceeding to next referral, 20 left
# Processing referral, 20 left out of 22
#
# ==== Patient 19 Generated ====
# Referral Rejected for Patient 19
# Referral processed, proceeding to next referral, 19 left
# Processing referral, 19 left out of 22
#
# ==== Patient 20 Generated ====
# Referral Accepted flag set to 1.0 for Patient 20
# Patient 20 Didn't Need Review
# Patient 20 Did Not Require Review, Rejection flag set to 0.0
# Patient 20 did not require a Review - go to opt-in
# Patient 20 Failed to Opt In
# Referral processed, proceeding to next referral, 18 left
# Processing referral, 18 left out of 22
#
# ==== Patient 21 Generated ====
# Referral Accepted flag set to 1.0 for Patient 21
# Patient 21 Didn't Need Review
# Patient 21 Did Not Require Review, Rejection flag set to 0.0
# Patient 21 did not require a Review - go to opt-in
# Patient 21 Failed to Opt In
# Referral processed, proceeding to next referral, 17 left
# Processing referral, 17 left out of 22
#
# ==== Patient 22 Generated ====
# Referral Accepted flag set to 1.0 for Patient 22
# Patient 22 Sent For Review
# Patient 22 Reviewed and Rejection flag set to 0.0
# Patient 22 Accepted at Review - go to opt-in
# Patient 22 Opted In
# Patient 22 requesting TA resource, current res level 36
# Referral processed, proceeding to next referral, 16 left
# Processing referral, 16 left out of 22
#
# ==== Patient 23 Generated ====
# Referral Accepted flag set to 1.0 for Patient 23
# Patient 23 Sent For Review
# Patient 23 Reviewed and Rejection flag set to 1.0
# Patient 23 Rejected at Review
# Patient 22 allocated TA resource, new res level 35
# Week 1: Patient number 22 (added week 1) put through TA
# Patient 22 waited 0 for assessment
# Patient 22 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 22 sent down **Step2** pathway
# PwP RUNNER: Patient 22 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_2 with a remaining caseload of 30 selected
# Referral processed, proceeding to next referral, 15 left
# Processing referral, 15 left out of 22
#
# ==== Patient 24 Generated ====
# Referral Accepted flag set to 1.0 for Patient 24
# Patient 24 Sent For Review
# Patient 24 Reviewed and Rejection flag set to 0.0
# Patient 24 Accepted at Review - go to opt-in
# Patient 24 Opted In
# Patient 24 requesting TA resource, current res level 35
# Referral processed, proceeding to next referral, 14 left
# Processing referral, 14 left out of 22
#
# ==== Patient 25 Generated ====
# Referral Rejected for Patient 25
# Patient 24 allocated TA resource, new res level 34
# Week 1: Patient number 24 (added week 1) put through TA
# Patient 24 waited 0 for assessment
# Patient 24 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 24 sent down **Step2** pathway
# PwP RUNNER: Patient 24 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_0 with a remaining caseload of 30 selected
# Resource PwP_2 with a caseload remaining of 29 allocated to patient 22
# Patient 22 added to caseload [] spaces left
# PwP RUNNER: Patient 22 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 1: Patient 22 (added week 1) put through PwP
# Patient 22 WEEK NUMBER 1 waited 0 weeks from 1 weeks to 1 to enter PwP treatment
# Random Session week 7 numbers are [1, 2, 3, 5, 7, 13, 16]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 1: Patient 22 (added week 1) on PwP Session 0 on Week 1
# FUNC PROCESS step2_pwp_process: Week 1: Patient 22 (added week 1) on PwP Session 1 on Week 2
# FUNC PROCESS step2_pwp_process: Week 1: Patient 22 (added week 1) on PwP Session 2 on Week 3
# FUNC PROCESS step2_pwp_process: Week 1: Patient 22 (added week 1) on PwP Session 3 on Week 5
# FUNC PROCESS step2_pwp_process: Week 1: Patient 22 (added week 1) on PwP Session 4 on Week 7
# FUNC PROCESS step2_pwp_process: Week 1: Patient 22 (added week 1) on PwP Session 5 on Week 13
# Resource PwP_2 usage recorded for week 16: {'week_number': 16, 'res_topup': 1}
# Referral processed, proceeding to next referral, 13 left
# Processing referral, 13 left out of 22
#
# ==== Patient 26 Generated ====
# Referral Accepted flag set to 1.0 for Patient 26
# Patient 26 Didn't Need Review
# Patient 26 Did Not Require Review, Rejection flag set to 0.0
# Patient 26 did not require a Review - go to opt-in
# Patient 26 Opted In
# Patient 26 requesting TA resource, current res level 34
# Referral processed, proceeding to next referral, 12 left
# Processing referral, 12 left out of 22
#
# ==== Patient 27 Generated ====
# Referral Rejected for Patient 27
# Patient 26 allocated TA resource, new res level 33
# Week 1: Patient number 26 (added week 1) put through TA
# Patient 26 waited 0 for assessment
# Patient 26 Accepted at TA Stage
# Selected step: **Step3**
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 26 sent down Step3 pathway
# FUNC PROCESS patient_step3_pathway: Patient 26 Initiating Couns Step 3 Route
# Couns RUNNER: Patient 26 added to Couns waiting list
# Resource Couns_2 with a remaining caseload of 25 selected
# Resource PwP_0 with a caseload remaining of 29 allocated to patient 24
# Patient 24 added to caseload [] spaces left
# PwP RUNNER: Patient 24 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 1: Patient 24 (added week 1) put through PwP
# Patient 24 WEEK NUMBER 1 waited 0 weeks from 1 weeks to 1 to enter PwP treatment
# Random Session week 7 numbers are [1, 2, 4, 5, 9, 12, 14]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 1: Patient 24 (added week 1) on PwP Session 0 on Week 1
# FUNC PROCESS step2_pwp_process: Week 1: Patient 24 (added week 1) on PwP Session 1 on Week 2
# FUNC PROCESS step2_pwp_process: Week 1: Patient 24 (added week 1) on PwP Session 2 on Week 4
# Patient 24 dropped out of PwP treatment
# Resource PwP_0 usage recorded for week 4: {'week_number': 4, 'res_topup': 1}
# Referral processed, proceeding to next referral, 11 left
# Processing referral, 11 left out of 22
#
# ==== Patient 28 Generated ====
# Referral Rejected for Patient 28
# Referral processed, proceeding to next referral, 10 left
# Processing referral, 10 left out of 22
#
# ==== Patient 29 Generated ====
# Referral Accepted flag set to 1.0 for Patient 29
# Patient 29 Sent For Review
# Patient 29 Reviewed and Rejection flag set to 0.0
# Patient 29 Accepted at Review - go to opt-in
# Patient 29 Failed to Opt In
# Resource Couns_2 with a caseload remaining of 24 allocated to patient 26
# Patient 26 added to caseload Couns_2, 24 spaces left
# Couns RUNNER: Patient 26 removed from Couns waiting list
# FUNC PROCESS step3_couns_process: Week 1: Patient 26 (added week 1) put through Couns
# Patient 26 WEEK NUMBER 1 waited 0 weeks from 1 weeks to 1 to enter Couns treatment
# Random Session week 9 numbers are [1, 3, 5, 8, 13, 15, 16, 18, 22]
# Number of sessions is 8
# FUNC PROCESS step3_couns_process: Week 1: Patient 26 (added week 1) on Couns Session 0 on Week 1
# FUNC PROCESS step3_couns_process: Week 1: Patient 26 (added week 1) on Couns Session 1 on Week 3
# FUNC PROCESS step3_couns_process: Week 1: Patient 26 (added week 1) on Couns Session 2 on Week 5
# FUNC PROCESS step3_couns_process: Week 1: Patient 26 (added week 1) on Couns Session 3 on Week 8
# FUNC PROCESS step3_couns_process: Week 1: Patient 26 (added week 1) on Couns Session 4 on Week 13
# Patient 26 dropped out of Couns treatment
# Resource Couns_2 usage recorded for week 13: {'week_number': 13, 'res_topup': 1}
# Referral processed, proceeding to next referral, 9 left
# Processing referral, 9 left out of 22
#
# ==== Patient 30 Generated ====
# Referral Accepted flag set to 1.0 for Patient 30
# Patient 30 Sent For Review
# Patient 30 Reviewed and Rejection flag set to 1.0
# Patient 30 Rejected at Review
# Referral processed, proceeding to next referral, 8 left
# Processing referral, 8 left out of 22
#
# ==== Patient 31 Generated ====
# Referral Rejected for Patient 31
# Referral processed, proceeding to next referral, 7 left
# Processing referral, 7 left out of 22
#
# ==== Patient 32 Generated ====
# Referral Accepted flag set to 1.0 for Patient 32
# Patient 32 Sent For Review
# Patient 32 Reviewed and Rejection flag set to 0.0
# Patient 32 Accepted at Review - go to opt-in
# Patient 32 Opted In
# Patient 32 requesting TA resource, current res level 33
# Referral processed, proceeding to next referral, 6 left
# Processing referral, 6 left out of 22
#
# ==== Patient 33 Generated ====
# Referral Accepted flag set to 1.0 for Patient 33
# Patient 33 Sent For Review
# Patient 33 Reviewed and Rejection flag set to 1.0
# Patient 33 Rejected at Review
# Patient 32 allocated TA resource, new res level 32
# Week 1: Patient number 32 (added week 1) put through TA
# Patient 32 waited 0 for assessment
# Patient 32 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 32 sent down **Step2** pathway
# PwP RUNNER: Patient 32 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_7 with a remaining caseload of 30 selected
# Referral processed, proceeding to next referral, 5 left
# Processing referral, 5 left out of 22
#
# ==== Patient 34 Generated ====
# Referral Accepted flag set to 1.0 for Patient 34
# Patient 34 Didn't Need Review
# Patient 34 Did Not Require Review, Rejection flag set to 0.0
# Patient 34 did not require a Review - go to opt-in
# Patient 34 Failed to Opt In
# Referral processed, proceeding to next referral, 4 left
# Processing referral, 4 left out of 22
#
# ==== Patient 35 Generated ====
# Referral Accepted flag set to 1.0 for Patient 35
# Patient 35 Didn't Need Review
# Patient 35 Did Not Require Review, Rejection flag set to 0.0
# Patient 35 did not require a Review - go to opt-in
# Patient 35 Failed to Opt In
# Resource PwP_7 with a caseload remaining of 29 allocated to patient 32
# Patient 32 added to caseload [] spaces left
# PwP RUNNER: Patient 32 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 1: Patient 32 (added week 1) put through PwP
# Patient 32 WEEK NUMBER 1 waited 0 weeks from 1 weeks to 1 to enter PwP treatment
# Random Session week 7 numbers are [1, 4, 8, 11, 13, 14, 15]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 1: Patient 32 (added week 1) on PwP Session 0 on Week 1
# FUNC PROCESS step2_pwp_process: Week 1: Patient 32 (added week 1) on PwP Session 1 on Week 4
# FUNC PROCESS step2_pwp_process: Week 1: Patient 32 (added week 1) on PwP Session 2 on Week 8
# FUNC PROCESS step2_pwp_process: Week 1: Patient 32 (added week 1) on PwP Session 3 on Week 11
# FUNC PROCESS step2_pwp_process: Week 1: Patient 32 (added week 1) on PwP Session 4 on Week 13
# FUNC PROCESS step2_pwp_process: Week 1: Patient 32 (added week 1) on PwP Session 5 on Week 14
# Patient 32 dropped out of PwP treatment
# Resource PwP_7 usage recorded for week 14: {'week_number': 14, 'res_topup': 1}
# Referral processed, proceeding to next referral, 3 left
# Processing referral, 3 left out of 22
#
# ==== Patient 36 Generated ====
# Referral Accepted flag set to 1.0 for Patient 36
# Patient 36 Didn't Need Review
# Patient 36 Did Not Require Review, Rejection flag set to 0.0
# Patient 36 did not require a Review - go to opt-in
# Patient 36 Opted In
# Patient 36 requesting TA resource, current res level 32
# Referral processed, proceeding to next referral, 2 left
# Processing referral, 2 left out of 22
#
# ==== Patient 37 Generated ====
# Referral Accepted flag set to 1.0 for Patient 37
# Patient 37 Sent For Review
# Patient 37 Reviewed and Rejection flag set to 1.0
# Patient 37 Rejected at Review
# Patient 36 allocated TA resource, new res level 31
# Week 1: Patient number 36 (added week 1) put through TA
# Patient 36 waited 0 for assessment
# Patient 36 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 36 sent down **Step2** pathway
# PwP RUNNER: Patient 36 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_10 with a remaining caseload of 30 selected
# Referral processed, proceeding to next referral, 1 left
# Processing referral, 1 left out of 22
#
# ==== Patient 38 Generated ====
# Referral Accepted flag set to 1.0 for Patient 38
# Patient 38 Didn't Need Review
# Patient 38 Did Not Require Review, Rejection flag set to 0.0
# Patient 38 did not require a Review - go to opt-in
# Patient 38 Opted In
# Patient 38 requesting TA resource, current res level 31
# Referral processed, proceeding to next referral, 0 left
#
# ==== Patient 39 Generated ====
# Referral Rejected for Patient 39
# Patient 38 allocated TA resource, new res level 30
# Week 1: Patient number 38 (added week 1) put through TA
# Patient 38 waited 0 for assessment
# Patient 38 Rejected at TA Stage
# Resource PwP_10 with a caseload remaining of 29 allocated to patient 36
# Patient 36 added to caseload [] spaces left
# PwP RUNNER: Patient 36 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 1: Patient 36 (added week 1) put through PwP
# Patient 36 WEEK NUMBER 1 waited 0 weeks from 1 weeks to 1 to enter PwP treatment
# Random Session week 7 numbers are [1, 3, 4, 9, 14, 15, 16]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 1: Patient 36 (added week 1) on PwP Session 0 on Week 1
# FUNC PROCESS step2_pwp_process: Week 1: Patient 36 (added week 1) on PwP Session 1 on Week 3
# FUNC PROCESS step2_pwp_process: Week 1: Patient 36 (added week 1) on PwP Session 2 on Week 4
# FUNC PROCESS step2_pwp_process: Week 1: Patient 36 (added week 1) on PwP Session 3 on Week 9
# FUNC PROCESS step2_pwp_process: Week 1: Patient 36 (added week 1) on PwP Session 4 on Week 14
# FUNC PROCESS step2_pwp_process: Week 1: Patient 36 (added week 1) on PwP Session 5 on Week 15
# Resource PwP_10 usage recorded for week 16: {'week_number': 16, 'res_topup': 1}
# Collecting Weekly Stats
# Weekly Stats have been collected
# Week 1 complete, moving on to Week 2
#
#                 #################################
#                         Week Number 2
#                 #################################
#
# Topping Up Resources
# TA Level: 30
# Putting in 6
# New TA Level: 36
# Topping Up Caseloads
# PwP Resource PwP_0 now at: 29
# PwP Resource PwP_1 now at: 30
# PwP Resource PwP_2 now at: 29
# PwP Resource PwP_3 now at: 30
# PwP Resource PwP_4 now at: 30
# PwP Resource PwP_5 at week 2: 29, 1 available to restore
# PwP Resource PwP_5 now at: 30
# PwP Resource PwP_6 now at: 29
# PwP Resource PwP_7 now at: 29
# PwP Resource PwP_8 now at: 30
# PwP Resource PwP_9 now at: 30
# PwP Resource PwP_10 now at: 29
# PwP Resource PwP_11 now at: 30
# Couns Resource CBT_0 now at: 25
# Couns Resource CBT_1 now at: 25
# Couns Resource CBT_2 now at: 25
# Couns Resource CBT_3 now at: 25
# Couns Resource CBT_4 now at: 25
# Couns Resource CBT_5 now at: 25
# Couns Resource CBT_6 now at: 25
# Couns Resource CBT_7 now at: 25
# Couns Resource CBT_8 now at: 25
# Couns Resource CBT_9 now at: 25
# Couns Resource CBT_10 now at: 25
# Couns Resource CBT_11 now at: 25
# Couns Resource CBT_12 now at: 25
# Couns Resource CBT_13 now at: 25
# PwP Resource Couns_0 now at: 25
# PwP Resource Couns_1 now at: 25
# PwP Resource Couns_2 now at: 24
# PwP Resource Couns_3 now at: 25
# Firing up the staff entity generator
#
# ==== PwP Staff 101.0 Generated ====
#
# ==== PwP Staff 102.0 Generated ====
#
# ==== PwP Staff 103.0 Generated ====
#
# ==== PwP Staff 104.0 Generated ====
#
# ==== PwP Staff 105.0 Generated ====
#
# ==== PwP Staff 106.0 Generated ====
#
# ==== PwP Staff 107.0 Generated ====
#
# ==== PwP Staff 108.0 Generated ====
#
# ==== PwP Staff 109.0 Generated ====
#
# ==== PwP Staff 110.0 Generated ====
#
# ==== PwP Staff 111.0 Generated ====
#
# ==== PwP Staff 112.0 Generated ====
#
# ==== PwP Staff 113.0 Generated ====
#
# ==== PwP Staff 114.0 Generated ====
#
# ==== PwP Staff 115.0 Generated ====
#
# ==== PwP Staff 116.0 Generated ====
#
# ==== PwP Staff 117.0 Generated ====
#
# ==== PwP Staff 118.0 Generated ====
#
# ==== PwP Staff 119.0 Generated ====
#
# ==== PwP Staff 120.0 Generated ====
#
# ==== PwP Staff 121.0 Generated ====
#
# ==== PwP Staff 122.0 Generated ====
#
# ==== PwP Staff 123.0 Generated ====
#
# ==== PwP Staff 124.0 Generated ====
#
# ==== CBT Staff 201.0 Generated ====
#
# ==== CBT Staff 202.0 Generated ====
#
# ==== CBT Staff 203.0 Generated ====
#
# ==== CBT Staff 204.0 Generated ====
#
# ==== CBT Staff 205.0 Generated ====
#
# ==== CBT Staff 206.0 Generated ====
#
# ==== CBT Staff 207.0 Generated ====
#
# ==== CBT Staff 208.0 Generated ====
#
# ==== CBT Staff 209.0 Generated ====
#
# ==== CBT Staff 210.0 Generated ====
#
# ==== CBT Staff 211.0 Generated ====
#
# ==== CBT Staff 212.0 Generated ====
#
# ==== CBT Staff 213.0 Generated ====
#
# ==== CBT Staff 214.0 Generated ====
#
# ==== CBT Staff 215.0 Generated ====
#
# ==== CBT Staff 216.0 Generated ====
#
# ==== CBT Staff 217.0 Generated ====
#
# ==== CBT Staff 218.0 Generated ====
#
# ==== CBT Staff 219.0 Generated ====
#
# ==== CBT Staff 220.0 Generated ====
#
# ==== CBT Staff 221.0 Generated ====
#
# ==== CBT Staff 222.0 Generated ====
#
# ==== CBT Staff 223.0 Generated ====
#
# ==== CBT Staff 224.0 Generated ====
#
# ==== CBT Staff 225.0 Generated ====
#
# ==== CBT Staff 226.0 Generated ====
#
# ==== CBT Staff 227.0 Generated ====
#
# ==== CBT Staff 228.0 Generated ====
#
# ==== Couns Staff 301.0 Generated ====
#
# ==== Couns Staff 302.0 Generated ====
#
# ==== Couns Staff 303.0 Generated ====
#
# ==== Couns Staff 304.0 Generated ====
#
# ==== Couns Staff 305.0 Generated ====
#
# ==== Couns Staff 306.0 Generated ====
#
# ==== Couns Staff 307.0 Generated ====
#
# ==== Couns Staff 308.0 Generated ====
# Staff generator complete
# Firing up the referral generator
# Week 2: 26 referrals generated
# Referral generator has returned 26 referrals
# Passing 26 to the patient treatment generator
# Processing 26 referral through treatment
# Processing referral, 26 left out of 26
# Referral processed, proceeding to next referral, 25 left
# Processing referral, 25 left out of 26
#
# ==== Patient 40 Generated ====
# Referral Rejected for Patient 40
# Referral processed, proceeding to next referral, 24 left
# Processing referral, 24 left out of 26
#
# ==== Patient 41 Generated ====
# Referral Accepted flag set to 1.0 for Patient 41
# Patient 41 Sent For Review
# Patient 41 Reviewed and Rejection flag set to 0.0
# Patient 41 Accepted at Review - go to opt-in
# Patient 41 Opted In
# Patient 41 requesting TA resource, current res level 36
# Referral processed, proceeding to next referral, 23 left
# Processing referral, 23 left out of 26
#
# ==== Patient 42 Generated ====
# Referral Accepted flag set to 1.0 for Patient 42
# Patient 42 Sent For Review
# Patient 42 Reviewed and Rejection flag set to 0.0
# Patient 42 Accepted at Review - go to opt-in
# Patient 42 Failed to Opt In
# Patient 41 allocated TA resource, new res level 35
# Week 2: Patient number 41 (added week 2) put through TA
# Patient 41 waited 0 for assessment
# Patient 41 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 41 sent down **Step2** pathway
# PwP RUNNER: Patient 41 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_2 with a remaining caseload of 29 selected
# Referral processed, proceeding to next referral, 22 left
# Processing referral, 22 left out of 26
#
# ==== Patient 43 Generated ====
# Referral Rejected for Patient 43
# Referral processed, proceeding to next referral, 21 left
# Processing referral, 21 left out of 26
#
# ==== Patient 44 Generated ====
# Referral Rejected for Patient 44
# Resource PwP_2 with a caseload remaining of 28 allocated to patient 41
# Patient 41 added to caseload [] spaces left
# PwP RUNNER: Patient 41 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 2: Patient 41 (added week 2) put through PwP
# Patient 41 WEEK NUMBER 2 waited 0 weeks from 2 weeks to 2 to enter PwP treatment
# Random Session week 7 numbers are [2, 5, 6, 12, 13, 15, 17]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 2: Patient 41 (added week 2) on PwP Session 0 on Week 2
# FUNC PROCESS step2_pwp_process: Week 2: Patient 41 (added week 2) on PwP Session 1 on Week 5
# FUNC PROCESS step2_pwp_process: Week 2: Patient 41 (added week 2) on PwP Session 2 on Week 6
# FUNC PROCESS step2_pwp_process: Week 2: Patient 41 (added week 2) on PwP Session 3 on Week 12
# Patient 41 dropped out of PwP treatment
# Resource PwP_2 usage recorded for week 12: {'week_number': 12, 'res_topup': 1}
# Referral processed, proceeding to next referral, 20 left
# Processing referral, 20 left out of 26
#
# ==== Patient 45 Generated ====
# Referral Rejected for Patient 45
# Referral processed, proceeding to next referral, 19 left
# Processing referral, 19 left out of 26
#
# ==== Patient 46 Generated ====
# Referral Accepted flag set to 1.0 for Patient 46
# Patient 46 Sent For Review
# Patient 46 Reviewed and Rejection flag set to 1.0
# Patient 46 Rejected at Review
# Referral processed, proceeding to next referral, 18 left
# Processing referral, 18 left out of 26
#
# ==== Patient 47 Generated ====
# Referral Accepted flag set to 1.0 for Patient 47
# Patient 47 Sent For Review
# Patient 47 Reviewed and Rejection flag set to 0.0
# Patient 47 Accepted at Review - go to opt-in
# Patient 47 Failed to Opt In
# Referral processed, proceeding to next referral, 17 left
# Processing referral, 17 left out of 26
#
# ==== Patient 48 Generated ====
# Referral Rejected for Patient 48
# Referral processed, proceeding to next referral, 16 left
# Processing referral, 16 left out of 26
#
# ==== Patient 49 Generated ====
# Referral Accepted flag set to 1.0 for Patient 49
# Patient 49 Sent For Review
# Patient 49 Reviewed and Rejection flag set to 1.0
# Patient 49 Rejected at Review
# Referral processed, proceeding to next referral, 15 left
# Processing referral, 15 left out of 26
#
# ==== Patient 50 Generated ====
# Referral Rejected for Patient 50
# Referral processed, proceeding to next referral, 14 left
# Processing referral, 14 left out of 26
#
# ==== Patient 51 Generated ====
# Referral Rejected for Patient 51
# Referral processed, proceeding to next referral, 13 left
# Processing referral, 13 left out of 26
#
# ==== Patient 52 Generated ====
# Referral Accepted flag set to 1.0 for Patient 52
# Patient 52 Didn't Need Review
# Patient 52 Did Not Require Review, Rejection flag set to 0.0
# Patient 52 did not require a Review - go to opt-in
# Patient 52 Opted In
# Patient 52 requesting TA resource, current res level 35
# Referral processed, proceeding to next referral, 12 left
# Processing referral, 12 left out of 26
#
# ==== Patient 53 Generated ====
# Referral Accepted flag set to 1.0 for Patient 53
# Patient 53 Sent For Review
# Patient 53 Reviewed and Rejection flag set to 0.0
# Patient 53 Accepted at Review - go to opt-in
# Patient 53 Failed to Opt In
# Patient 52 allocated TA resource, new res level 34
# Week 2: Patient number 52 (added week 2) put through TA
# Patient 52 waited 0 for assessment
# Patient 52 Accepted at TA Stage
# Selected step: **Step3**
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 52 sent down Step3 pathway
# FUNC PROCESS patient_step3_pathway: Patient 52 Initiating CBT Step 3 Route
# CBT RUNNER: Patient 52 added to CBT waiting list
# Resource CBT_6 with a remaining caseload of 25 selected
# Referral processed, proceeding to next referral, 11 left
# Processing referral, 11 left out of 26
#
# ==== Patient 54 Generated ====
# Referral Accepted flag set to 1.0 for Patient 54
# Patient 54 Didn't Need Review
# Patient 54 Did Not Require Review, Rejection flag set to 0.0
# Patient 54 did not require a Review - go to opt-in
# Patient 54 Opted In
# Patient 54 requesting TA resource, current res level 34
# Resource CBT_6 with a caseload remaining of 25 allocated to patient 52
# Patient 52 added to caseload CBT_6, 25 spaces left
# CBT RUNNER: Patient 52 removed from CBT waiting list
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) put through CBT
# Patient 52 WEEK NUMBER 2 waited 0 weeks from 2 weeks to 2 to enter CBT treatment
# Random Session week 28 numbers are [2, 3, 4, 14, 22, 25, 27, 40, 42, 47, 58, 70, 73, 77, 92, 93, 98, 100, 101, 102, 108, 115, 117, 125, 131, 133, 135, 138]
# Number of sessions is 27
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) on CBT Session 0 on Week 2
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) on CBT Session 1 on Week 3
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) on CBT Session 2 on Week 4
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) on CBT Session 3 on Week 14
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) on CBT Session 4 on Week 22
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) on CBT Session 5 on Week 25
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) on CBT Session 6 on Week 27
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) on CBT Session 7 on Week 40
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) on CBT Session 8 on Week 42
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) on CBT Session 9 on Week 47
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) on CBT Session 10 on Week 58
# FUNC PROCESS step3_cbt_process: Week 2: Patient 52 (added week 2) on CBT Session 11 on Week 70
# Resource CBT_6 usage recorded for week 138: {'week_number': 138, 'res_topup': 1}
# Referral processed, proceeding to next referral, 10 left
# Processing referral, 10 left out of 26
#
# ==== Patient 55 Generated ====
# Referral Rejected for Patient 55
# Patient 54 allocated TA resource, new res level 33
# Week 2: Patient number 54 (added week 2) put through TA
# Patient 54 waited 0 for assessment
# Patient 54 Rejected at TA Stage
# Referral processed, proceeding to next referral, 9 left
# Processing referral, 9 left out of 26
#
# ==== Patient 56 Generated ====
# Referral Accepted flag set to 1.0 for Patient 56
# Patient 56 Sent For Review
# Patient 56 Reviewed and Rejection flag set to 0.0
# Patient 56 Accepted at Review - go to opt-in
# Patient 56 Opted In
# Patient 56 requesting TA resource, current res level 33
# Referral processed, proceeding to next referral, 8 left
# Processing referral, 8 left out of 26
#
# ==== Patient 57 Generated ====
# Referral Rejected for Patient 57
# Patient 56 allocated TA resource, new res level 32
# Week 2: Patient number 56 (added week 2) put through TA
# Patient 56 waited 0 for assessment
# Patient 56 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 56 sent down **Step2** pathway
# Patient 56 sent to Group store
# Group store contains 1 of possible 7
# Referral processed, proceeding to next referral, 7 left
# Processing referral, 7 left out of 26
#
# ==== Patient 58 Generated ====
# Referral Accepted flag set to 1.0 for Patient 58
# Patient 58 Didn't Need Review
# Patient 58 Did Not Require Review, Rejection flag set to 0.0
# Patient 58 did not require a Review - go to opt-in
# Patient 58 Opted In
# Patient 58 requesting TA resource, current res level 32
# Referral processed, proceeding to next referral, 6 left
# Processing referral, 6 left out of 26
#
# ==== Patient 59 Generated ====
# Referral Accepted flag set to 1.0 for Patient 59
# Patient 59 Sent For Review
# Patient 59 Reviewed and Rejection flag set to 1.0
# Patient 59 Rejected at Review
# Patient 58 allocated TA resource, new res level 31
# Week 2: Patient number 58 (added week 2) put through TA
# Patient 58 waited 0 for assessment
# Patient 58 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 58 sent down **Step2** pathway
# PwP RUNNER: Patient 58 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_2 with a remaining caseload of 28 selected
# Referral processed, proceeding to next referral, 5 left
# Processing referral, 5 left out of 26
#
# ==== Patient 60 Generated ====
# Referral Accepted flag set to 1.0 for Patient 60
# Patient 60 Didn't Need Review
# Patient 60 Did Not Require Review, Rejection flag set to 0.0
# Patient 60 did not require a Review - go to opt-in
# Patient 60 Failed to Opt In
# Referral processed, proceeding to next referral, 4 left
# Processing referral, 4 left out of 26
#
# ==== Patient 61 Generated ====
# Referral Rejected for Patient 61
# Resource PwP_2 with a caseload remaining of 27 allocated to patient 58
# Patient 58 added to caseload [] spaces left
# PwP RUNNER: Patient 58 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) put through PwP
# Patient 58 WEEK NUMBER 2 waited 0 weeks from 2 weeks to 2 to enter PwP treatment
# Random Session week 7 numbers are [2, 5, 7, 12, 13, 14, 16]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) on PwP Session 0 on Week 2
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) on PwP Session 1 on Week 5
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) on PwP Session 2 on Week 7
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) on PwP Session 3 on Week 12
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) on PwP Session 4 on Week 13
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) on PwP Session 5 on Week 14
# Patient 58 dropped out of PwP treatment
# Resource PwP_2 usage recorded for week 14: {'week_number': 14, 'res_topup': 1}
# Referral processed, proceeding to next referral, 3 left
# Processing referral, 3 left out of 26
#
# ==== Patient 62 Generated ====
# Referral Rejected for Patient 62
# Referral processed, proceeding to next referral, 2 left
# Processing referral, 2 left out of 26
#
# ==== Patient 63 Generated ====
# Referral Accepted flag set to 1.0 for Patient 63
# Patient 63 Sent For Review
# Patient 63 Reviewed and Rejection flag set to 1.0
# Patient 63 Rejected at Review
# Referral processed, proceeding to next referral, 1 left
# Processing referral, 1 left out of 26
#
# ==== Patient 64 Generated ====
# Referral Accepted flag set to 1.0 for Patient 64
# Patient 64 Sent For Review
# Patient 64 Reviewed and Rejection flag set to 1.0
# Patient 64 Rejected at Review
# Referral processed, proceeding to next referral, 0 left
#
# ==== Patient 65 Generated ====
# Referral Accepted flag set to 1.0 for Patient 65
# Patient 65 Sent For Review
# Patient 65 Reviewed and Rejection flag set to 0.0
# Patient 65 Accepted at Review - go to opt-in
# Patient 65 Failed to Opt In
# Collecting Weekly Stats
# Weekly Stats have been collected
# {'PwP_0': {}, 'PwP_1': {}, 'PwP_2': {}, 'PwP_3': {}, 'PwP_4': {}, 'PwP_5': {}, 'PwP_6': {}, 'PwP_7': {}, 'PwP_8': {}, 'PwP_9': {}, 'PwP_10': {}, 'PwP_11': {}}
# {'CBT_0': {}, 'CBT_1': {}, 'CBT_2': {}, 'CBT_3': {}, 'CBT_4': {}, 'CBT_5': {}, 'CBT_6': {}, 'CBT_7': {}, 'CBT_8': {}, 'CBT_9': {}, 'CBT_10': {}, 'CBT_11': {}, 'CBT_12': {}, 'CBT_13': {}}
# {'Couns_0': {}, 'Couns_1': {}, 'Couns_2': {}, 'Couns_3': {}}
# Building Sim Resources
# Sim Resources Ready
# Caseload Resources Ready
#
#                 #################################
#                         Week Number 0
#                 #################################
#
# Topping Up Resources
# Topping Up Caseloads
# PwP Resource PwP_0 now at: 30
# PwP Resource PwP_1 now at: 30
# PwP Resource PwP_2 now at: 30
# PwP Resource PwP_3 now at: 30
# PwP Resource PwP_4 now at: 30
# PwP Resource PwP_5 now at: 30
# PwP Resource PwP_6 now at: 30
# PwP Resource PwP_7 now at: 30
# PwP Resource PwP_8 now at: 30
# PwP Resource PwP_9 now at: 30
# PwP Resource PwP_10 now at: 30
# PwP Resource PwP_11 now at: 30
# Couns Resource CBT_0 now at: 25
# Couns Resource CBT_1 now at: 25
# Couns Resource CBT_2 now at: 25
# Couns Resource CBT_3 now at: 25
# Couns Resource CBT_4 now at: 25
# Couns Resource CBT_5 now at: 25
# Couns Resource CBT_6 now at: 25
# Couns Resource CBT_7 now at: 25
# Couns Resource CBT_8 now at: 25
# Couns Resource CBT_9 now at: 25
# Couns Resource CBT_10 now at: 25
# Couns Resource CBT_11 now at: 25
# Couns Resource CBT_12 now at: 25
# Couns Resource CBT_13 now at: 25
# PwP Resource Couns_0 now at: 25
# PwP Resource Couns_1 now at: 25
# PwP Resource Couns_2 now at: 25
# PwP Resource Couns_3 now at: 25
# Firing up the staff entity generator
#
# ==== PwP Staff 101.0 Generated ====
#
# ==== PwP Staff 102.0 Generated ====
#
# ==== PwP Staff 103.0 Generated ====
#
# ==== PwP Staff 104.0 Generated ====
#
# ==== PwP Staff 105.0 Generated ====
#
# ==== PwP Staff 106.0 Generated ====
#
# ==== PwP Staff 107.0 Generated ====
#
# ==== PwP Staff 108.0 Generated ====
#
# ==== PwP Staff 109.0 Generated ====
#
# ==== PwP Staff 110.0 Generated ====
#
# ==== PwP Staff 111.0 Generated ====
#
# ==== PwP Staff 112.0 Generated ====
#
# ==== PwP Staff 113.0 Generated ====
#
# ==== PwP Staff 114.0 Generated ====
#
# ==== PwP Staff 115.0 Generated ====
#
# ==== PwP Staff 116.0 Generated ====
#
# ==== PwP Staff 117.0 Generated ====
#
# ==== PwP Staff 118.0 Generated ====
#
# ==== PwP Staff 119.0 Generated ====
#
# ==== PwP Staff 120.0 Generated ====
#
# ==== PwP Staff 121.0 Generated ====
#
# ==== PwP Staff 122.0 Generated ====
#
# ==== PwP Staff 123.0 Generated ====
#
# ==== PwP Staff 124.0 Generated ====
#
# ==== CBT Staff 201.0 Generated ====
#
# ==== CBT Staff 202.0 Generated ====
#
# ==== CBT Staff 203.0 Generated ====
#
# ==== CBT Staff 204.0 Generated ====
#
# ==== CBT Staff 205.0 Generated ====
#
# ==== CBT Staff 206.0 Generated ====
#
# ==== CBT Staff 207.0 Generated ====
#
# ==== CBT Staff 208.0 Generated ====
#
# ==== CBT Staff 209.0 Generated ====
#
# ==== CBT Staff 210.0 Generated ====
#
# ==== CBT Staff 211.0 Generated ====
#
# ==== CBT Staff 212.0 Generated ====
#
# ...
# Processing referral, 21 left out of 26
#
# ==== Patient 44 Generated ====
# Referral Accepted flag set to 1.0 for Patient 44
# Patient 44 Didn't Need Review
# Patient 44 Did Not Require Review, Rejection flag set to 0.0
# Patient 44 did not require a Review - go to opt-in
# Patient 44 Opted In
# Patient 44 requesting TA resource, current res level 34
# Referral processed, proceeding to next referral, 20 left
# Processing referral, 20 left out of 26
#
# ==== Patient 45 Generated ====
# Referral Accepted flag set to 1.0 for Patient 45
# Patient 45 Sent For Review
# Patient 45 Reviewed and Rejection flag set to 1.0
# Patient 45 Rejected at Review
# Patient 44 allocated TA resource, new res level 33
# Week 2: Patient number 44 (added week 2) put through TA
# Patient 44 waited 0 for assessment
# Patient 44 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 44 sent down **Step2** pathway
# PwP RUNNER: Patient 44 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_7 with a remaining caseload of 29 selected
# Referral processed, proceeding to next referral, 19 left
# Processing referral, 19 left out of 26
#
# ==== Patient 46 Generated ====
# Referral Accepted flag set to 1.0 for Patient 46
# Patient 46 Didn't Need Review
# Patient 46 Did Not Require Review, Rejection flag set to 0.0
# Patient 46 did not require a Review - go to opt-in
# Patient 46 Opted In
# Patient 46 requesting TA resource, current res level 33
# Referral processed, proceeding to next referral, 18 left
# Processing referral, 18 left out of 26
#
# ==== Patient 47 Generated ====
# Referral Accepted flag set to 1.0 for Patient 47
# Patient 47 Sent For Review
# Patient 47 Reviewed and Rejection flag set to 0.0
# Patient 47 Accepted at Review - go to opt-in
# Patient 47 Opted In
# Patient 47 requesting TA resource, current res level 32
# Patient 46 allocated TA resource, new res level 31
# Week 2: Patient number 46 (added week 2) put through TA
# Patient 46 waited 0 for assessment
# Patient 46 Rejected at TA Stage
# Resource PwP_7 with a caseload remaining of 28 allocated to patient 44
# Patient 44 added to caseload [] spaces left
# PwP RUNNER: Patient 44 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 2: Patient 44 (added week 2) put through PwP
# Patient 44 WEEK NUMBER 2 waited 0 weeks from 2 weeks to 2 to enter PwP treatment
# Random Session week 7 numbers are [2, 4, 5, 8, 9, 15, 16]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 2: Patient 44 (added week 2) on PwP Session 0 on Week 2
# FUNC PROCESS step2_pwp_process: Week 2: Patient 44 (added week 2) on PwP Session 1 on Week 4
# FUNC PROCESS step2_pwp_process: Week 2: Patient 44 (added week 2) on PwP Session 2 on Week 5
# FUNC PROCESS step2_pwp_process: Week 2: Patient 44 (added week 2) on PwP Session 3 on Week 8
# FUNC PROCESS step2_pwp_process: Week 2: Patient 44 (added week 2) on PwP Session 4 on Week 9
# Patient 44 dropped out of PwP treatment
# Resource PwP_7 usage recorded for week 9: {'week_number': 9, 'res_topup': 1}
# Referral processed, proceeding to next referral, 17 left
# Processing referral, 17 left out of 26
#
# ==== Patient 48 Generated ====
# Referral Rejected for Patient 48
# Patient 47 allocated TA resource, new res level 31
# Week 2: Patient number 47 (added week 2) put through TA
# Patient 47 waited 0 for assessment
# Patient 47 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 47 sent down **Step2** pathway
# PwP RUNNER: Patient 47 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_6 with a remaining caseload of 30 selected
# Referral processed, proceeding to next referral, 16 left
# Processing referral, 16 left out of 26
#
# ==== Patient 49 Generated ====
# Referral Rejected for Patient 49
# Referral processed, proceeding to next referral, 15 left
# Processing referral, 15 left out of 26
#
# ==== Patient 50 Generated ====
# Referral Accepted flag set to 1.0 for Patient 50
# Patient 50 Sent For Review
# Patient 50 Reviewed and Rejection flag set to 1.0
# Patient 50 Rejected at Review
# Resource PwP_6 with a caseload remaining of 29 allocated to patient 47
# Patient 47 added to caseload [] spaces left
# PwP RUNNER: Patient 47 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 2: Patient 47 (added week 2) put through PwP
# Patient 47 WEEK NUMBER 2 waited 0 weeks from 2 weeks to 2 to enter PwP treatment
# Random Session week 7 numbers are [2, 4, 5, 6, 7, 8, 9]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 2: Patient 47 (added week 2) on PwP Session 0 on Week 2
# FUNC PROCESS step2_pwp_process: Week 2: Patient 47 (added week 2) on PwP Session 1 on Week 4
# FUNC PROCESS step2_pwp_process: Week 2: Patient 47 (added week 2) on PwP Session 2 on Week 5
# FUNC PROCESS step2_pwp_process: Week 2: Patient 47 (added week 2) on PwP Session 3 on Week 6
# FUNC PROCESS step2_pwp_process: Week 2: Patient 47 (added week 2) on PwP Session 4 on Week 7
# FUNC PROCESS step2_pwp_process: Week 2: Patient 47 (added week 2) on PwP Session 5 on Week 8
# Resource PwP_6 usage recorded for week 9: {'week_number': 9, 'res_topup': 1}
# Referral processed, proceeding to next referral, 14 left
# Processing referral, 14 left out of 26
#
# ==== Patient 51 Generated ====
# Referral Rejected for Patient 51
# Referral processed, proceeding to next referral, 13 left
# Processing referral, 13 left out of 26
#
# ==== Patient 52 Generated ====
# Referral Rejected for Patient 52
# Referral processed, proceeding to next referral, 12 left
# Processing referral, 12 left out of 26
#
# ==== Patient 53 Generated ====
# Referral Accepted flag set to 1.0 for Patient 53
# Patient 53 Didn't Need Review
# Patient 53 Did Not Require Review, Rejection flag set to 0.0
# Patient 53 did not require a Review - go to opt-in
# Patient 53 Opted In
# Patient 53 requesting TA resource, current res level 31
# Referral processed, proceeding to next referral, 11 left
# Processing referral, 11 left out of 26
#
# ==== Patient 54 Generated ====
# Referral Rejected for Patient 54
# Patient 53 allocated TA resource, new res level 30
# Week 2: Patient number 53 (added week 2) put through TA
# Patient 53 waited 0 for assessment
# Patient 53 Rejected at TA Stage
# Referral processed, proceeding to next referral, 10 left
# Processing referral, 10 left out of 26
#
# ==== Patient 55 Generated ====
# Referral Accepted flag set to 1.0 for Patient 55
# Patient 55 Didn't Need Review
# Patient 55 Did Not Require Review, Rejection flag set to 0.0
# Patient 55 did not require a Review - go to opt-in
# Patient 55 Opted In
# Patient 55 requesting TA resource, current res level 30
# Referral processed, proceeding to next referral, 9 left
# Processing referral, 9 left out of 26
#
# ==== Patient 56 Generated ====
# Referral Accepted flag set to 1.0 for Patient 56
# Patient 56 Didn't Need Review
# Patient 56 Did Not Require Review, Rejection flag set to 0.0
# Patient 56 did not require a Review - go to opt-in
# Patient 56 Opted In
# Patient 56 requesting TA resource, current res level 29
# Patient 55 allocated TA resource, new res level 28
# Week 2: Patient number 55 (added week 2) put through TA
# Patient 55 waited 0 for assessment
# Patient 55 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 55 sent down **Step2** pathway
# PwP RUNNER: Patient 55 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_3 with a remaining caseload of 30 selected
# Referral processed, proceeding to next referral, 8 left
# Processing referral, 8 left out of 26
#
# ==== Patient 57 Generated ====
# Referral Accepted flag set to 1.0 for Patient 57
# Patient 57 Didn't Need Review
# Patient 57 Did Not Require Review, Rejection flag set to 0.0
# Patient 57 did not require a Review - go to opt-in
# Patient 57 Failed to Opt In
# Patient 56 allocated TA resource, new res level 28
# Week 2: Patient number 56 (added week 2) put through TA
# Patient 56 waited 0 for assessment
# Patient 56 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 56 sent down **Step2** pathway
# PwP RUNNER: Patient 56 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_0 with a remaining caseload of 30 selected
# Referral processed, proceeding to next referral, 7 left
# Processing referral, 7 left out of 26
#
# ==== Patient 58 Generated ====
# Referral Accepted flag set to 1.0 for Patient 58
# Patient 58 Sent For Review
# Patient 58 Reviewed and Rejection flag set to 0.0
# Patient 58 Accepted at Review - go to opt-in
# Patient 58 Opted In
# Patient 58 requesting TA resource, current res level 28
# Resource PwP_0 with a caseload remaining of 29 allocated to patient 55
# Patient 55 added to caseload [] spaces left
# PwP RUNNER: Patient 55 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 2: Patient 55 (added week 2) put through PwP
# Patient 55 WEEK NUMBER 2 waited 0 weeks from 2 weeks to 2 to enter PwP treatment
# Random Session week 7 numbers are [2, 7, 11, 12, 13, 14, 15]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 2: Patient 55 (added week 2) on PwP Session 0 on Week 2
# FUNC PROCESS step2_pwp_process: Week 2: Patient 55 (added week 2) on PwP Session 1 on Week 7
# FUNC PROCESS step2_pwp_process: Week 2: Patient 55 (added week 2) on PwP Session 2 on Week 11
# FUNC PROCESS step2_pwp_process: Week 2: Patient 55 (added week 2) on PwP Session 3 on Week 12
# FUNC PROCESS step2_pwp_process: Week 2: Patient 55 (added week 2) on PwP Session 4 on Week 13
# FUNC PROCESS step2_pwp_process: Week 2: Patient 55 (added week 2) on PwP Session 5 on Week 14
# Resource PwP_0 usage recorded for week 15: {'week_number': 15, 'res_topup': 1}
# Referral processed, proceeding to next referral, 6 left
# Processing referral, 6 left out of 26
#
# ==== Patient 59 Generated ====
# Referral Accepted flag set to 1.0 for Patient 59
# Patient 59 Sent For Review
# Patient 59 Reviewed and Rejection flag set to 0.0
# Patient 59 Accepted at Review - go to opt-in
# Patient 59 Opted In
# Patient 59 requesting TA resource, current res level 27
# Patient 58 allocated TA resource, new res level 26
# Week 2: Patient number 58 (added week 2) put through TA
# Patient 58 waited 0 for assessment
# Patient 58 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 58 sent down **Step2** pathway
# PwP RUNNER: Patient 58 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_10 with a remaining caseload of 30 selected
# Resource PwP_0 with a caseload remaining of 29 allocated to patient 56
# Patient 56 added to caseload [] spaces left
# PwP RUNNER: Patient 56 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 2: Patient 56 (added week 2) put through PwP
# Patient 56 WEEK NUMBER 2 waited 0 weeks from 2 weeks to 2 to enter PwP treatment
# Random Session week 7 numbers are [2, 3, 4, 6, 12, 13, 17]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 2: Patient 56 (added week 2) on PwP Session 0 on Week 2
# FUNC PROCESS step2_pwp_process: Week 2: Patient 56 (added week 2) on PwP Session 1 on Week 3
# FUNC PROCESS step2_pwp_process: Week 2: Patient 56 (added week 2) on PwP Session 2 on Week 4
# FUNC PROCESS step2_pwp_process: Week 2: Patient 56 (added week 2) on PwP Session 3 on Week 6
# FUNC PROCESS step2_pwp_process: Week 2: Patient 56 (added week 2) on PwP Session 4 on Week 12
# FUNC PROCESS step2_pwp_process: Week 2: Patient 56 (added week 2) on PwP Session 5 on Week 13
# Resource PwP_0 usage recorded for week 17: {'week_number': 17, 'res_topup': 1}
# Referral processed, proceeding to next referral, 5 left
# Processing referral, 5 left out of 26
#
# ==== Patient 60 Generated ====
# Referral Rejected for Patient 60
# Patient 59 allocated TA resource, new res level 26
# Week 2: Patient number 59 (added week 2) put through TA
# Patient 59 waited 0 for assessment
# Patient 59 Rejected at TA Stage
# Referral processed, proceeding to next referral, 4 left
# Processing referral, 4 left out of 26
#
# ==== Patient 61 Generated ====
# Referral Accepted flag set to 1.0 for Patient 61
# Patient 61 Sent For Review
# Patient 61 Reviewed and Rejection flag set to 1.0
# Patient 61 Rejected at Review
# Resource PwP_10 with a caseload remaining of 29 allocated to patient 58
# Patient 58 added to caseload [] spaces left
# PwP RUNNER: Patient 58 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) put through PwP
# Patient 58 WEEK NUMBER 2 waited 0 weeks from 2 weeks to 2 to enter PwP treatment
# Random Session week 7 numbers are [2, 3, 5, 6, 12, 15, 16]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) on PwP Session 0 on Week 2
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) on PwP Session 1 on Week 3
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) on PwP Session 2 on Week 5
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) on PwP Session 3 on Week 6
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) on PwP Session 4 on Week 12
# FUNC PROCESS step2_pwp_process: Week 2: Patient 58 (added week 2) on PwP Session 5 on Week 15
# Resource PwP_10 usage recorded for week 16: {'week_number': 16, 'res_topup': 1}
# Referral processed, proceeding to next referral, 3 left
# Processing referral, 3 left out of 26
#
# ==== Patient 62 Generated ====
# Referral Rejected for Patient 62
# Referral processed, proceeding to next referral, 2 left
# Processing referral, 2 left out of 26
#
# ==== Patient 63 Generated ====
# Referral Accepted flag set to 1.0 for Patient 63
# Patient 63 Didn't Need Review
# Patient 63 Did Not Require Review, Rejection flag set to 0.0
# Patient 63 did not require a Review - go to opt-in
# Patient 63 Opted In
# Patient 63 requesting TA resource, current res level 26
# Referral processed, proceeding to next referral, 1 left
# Processing referral, 1 left out of 26
#
# ==== Patient 64 Generated ====
# Referral Accepted flag set to 1.0 for Patient 64
# Patient 64 Sent For Review
# Patient 64 Reviewed and Rejection flag set to 0.0
# Patient 64 Accepted at Review - go to opt-in
# Patient 64 Opted In
# Patient 64 requesting TA resource, current res level 25
# Patient 63 allocated TA resource, new res level 24
# Week 2: Patient number 63 (added week 2) put through TA
# Patient 63 waited 0 for assessment
# Patient 63 Accepted at TA Stage
# Selected step: Step2
# -- Pathway Runner Initiated --
# PATHWAY RUNNER: Patient 63 sent down **Step2** pathway
# PwP RUNNER: Patient 63 added to PwP waiting list
# Patient sent down PwP
# Resource PwP_6 with a remaining caseload of 29 selected
# Referral processed, proceeding to next referral, 0 left
#
# ==== Patient 65 Generated ====
# Referral Rejected for Patient 65
# Patient 64 allocated TA resource, new res level 24
# Week 2: Patient number 64 (added week 2) put through TA
# Patient 64 waited 0 for assessment
# Patient 64 Rejected at TA Stage
# Collecting Weekly Stats
# Resource PwP_6 with a caseload remaining of 28 allocated to patient 63
# Patient 63 added to caseload [] spaces left
# PwP RUNNER: Patient 63 removed from PwP waiting list
# FUNC PROCESS step2_pwp_process: Week 2: Patient 63 (added week 2) put through PwP
# Patient 63 WEEK NUMBER 2 waited 0 weeks from 2 weeks to 2 to enter PwP treatment
# Random Session week 7 numbers are [2, 7, 10, 11, 14, 15, 16]
# Number of sessions is 6
# FUNC PROCESS step2_pwp_process: Week 2: Patient 63 (added week 2) on PwP Session 0 on Week 2
# FUNC PROCESS step2_pwp_process: Week 2: Patient 63 (added week 2) on PwP Session 1 on Week 7
# FUNC PROCESS step2_pwp_process: Week 2: Patient 63 (added week 2) on PwP Session 2 on Week 10
# FUNC PROCESS step2_pwp_process: Week 2: Patient 63 (added week 2) on PwP Session 3 on Week 11
# Patient 63 dropped out of PwP treatment
# Resource PwP_6 usage recorded for week 11: {'week_number': 11, 'res_topup': 1}
# Weekly Stats have been collected
# c:\HSMA\_Student_Code\heath_iapt_fork\hm-hsma-IAPT-Pathway-DES\iapt_classes_model.py:869: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9017251517751155' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.asst_results_df.at[p.id, 'Review Wait'] = random.uniform(0,

# %%
asst_weekly_dfs
# Out:
#    Run Number  Week Number  Referrals Received  Referral Screen Mins  \
# 0           0            0                  17            337.319801
# 1           0            1                  22            779.925624
# 2           0            2                  26           1303.323422
# 0           1            0                  17            326.102587
# 1           1            1                  22            770.732829
# 2           1            2                  26           1265.021714
#
#    Referrals Accepted  Referrals Rejected  Referrals Reviewed  \
# 0                 2.0                 5.0                 9.0
# 1                 7.0                12.0                17.0
# 2                11.0                23.0                28.0
# 0                 3.0                 6.0                 6.0
# 1                 8.0                14.0                14.0
# 2                16.0                24.0                22.0
#
#    Reviews Rejected  Referrals Delay Opt-in  Referrals Opted-in  \
# 0               7.0                0.224942                 3.0
# 1              11.0                0.308358                 9.0
# 2              16.0                0.294396                14.0
# 0               2.0                0.193305                 5.0
# 1               8.0                0.287178                12.0
# 2              11.0                0.322250                24.0
#
#    Referrals Wait Opt-in  TA Waiting List  TA Avg Wait  TA Total Accept  \
# 0               0.818243                0          0.0              2.0
# 1               1.213850                0          0.0              7.0
# 2               1.132193                0          0.0             11.0
# 0               1.680788                0          0.0              3.0
# 1               1.776972                1          0.0              8.0
# 2               1.728303                0          0.0             16.0
#
#    TA Mins  Run
# 0    180.0    0
# 1    537.0    0
# 2    835.0    0
# 0    301.0    1
# 1    658.0    1
# 2   1418.0    1
